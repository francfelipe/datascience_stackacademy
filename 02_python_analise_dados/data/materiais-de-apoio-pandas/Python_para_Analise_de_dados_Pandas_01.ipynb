# %% [markdown]
# # Python para Análise de Dados - Pandas

# %% [markdown]
# Iremos trabalhar com base de imóveis que obtive no site **Kaggle**

# %%
# Importando o Pandas.
import pandas as pd

# %%
# Lendo uma base de dados no formato .csv.
# o parâmetro sep é usado para definir qual o separador entre os dados.
# o parâmetro header informo em qual linha está minhas colunas ou se elas não existem.
# Se não existe colunas (header=None) o pandas dará um número para cada atributo da base.
arquivo = 'kc_house_data.csv'
dataset = pd.read_csv(arquivo, sep=',' ,header=0)

# %%
# Imprimindo o tipo da variável dataset
# Dataframe é um estrutura de dados onde linhas podem ter colunas de diferentes tipos.
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
# Metodo head() imprime as 5 linhas iniciais do dataframe.
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# O parâmetro index_col informa a coluna na qual o dataframe será indexado
dataset = pd.read_csv(arquivo, sep=',', index_col='date')

# %%
dataset = pd.read_csv(arquivo, sep=',', usecols=['id','date','price','bedrooms'])

# %%
# Metodo head() imprime as 5 linhas iniciais do dataframe.
dataset.head()
# Out:
#            id             date     price  bedrooms
# 0  7129300520  20141013T000000  221900.0       3.0
# 1  6414100192  20141209T000000  538000.0       3.0
# 2  5631500400  20150225T000000  180000.0       2.0
# 3  2487200875  20141209T000000  604000.0       4.0
# 4  1954400510  20150218T000000  510000.0       3.0

# %%
# Imprimindo a 100 primeiras linhas do dataframe.
dataset.head(100)
# Out:
#             id             date     price  bedrooms
# 0   7129300520  20141013T000000  221900.0       3.0
# 1   6414100192  20141209T000000  538000.0       3.0
# 2   5631500400  20150225T000000  180000.0       2.0
# 3   2487200875  20141209T000000  604000.0       4.0
# 4   1954400510  20150218T000000  510000.0       3.0
# ..         ...              ...       ...       ...
# 95  1483300570  20140908T000000  905000.0       4.0
# 96  3422049190  20150330T000000  247500.0       3.0
# 97  1099611230  20140912T000000  199000.0       4.0
# 98   722079104  20140711T000000  314000.0       3.0
# 99  7338200240  20140516T000000  437500.0       3.0
#
# [100 rows x 4 columns]

# %%
# Atributo columns retorna o nome das colunas do dataframe.
dataset.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms'], dtype='object')

# %%
# Método count() retorna a quantidade de linhas de todas as colunas.
dataset.count()
# Out:
# id          21613
# date        21613
# price       21613
# bedrooms    21609
# dtype: int64

# %%
# Método describe() exibe informações estatísticas da base de dados. 
# Várias informações como desvio padrão, média, valor mínimo e valor máximo de colunas.
dataset.describe()
# Out:
#                  id         price      bedrooms
# count  2.161300e+04  2.161300e+04  21609.000000
# mean   4.580302e+09  5.400881e+05      3.370910
# std    2.876566e+09  3.671272e+05      0.930084
# min    1.000102e+06  7.500000e+04      0.000000
# 25%    2.123049e+09  3.219500e+05      3.000000
# 50%    3.904930e+09  4.500000e+05      3.000000
# 75%    7.308900e+09  6.450000e+05      4.000000
# max    9.900000e+09  7.700000e+06     33.000000

# %%
# Imprime as 5 ultimas linhas .
dataset.tail(100)
# Out:
#                id             date      price  bedrooms
# 21513  1023059465  20140513T000000   505000.0       4.0
# 21514  3262300818  20150227T000000  1865000.0       4.0
# 21515  2937300040  20141215T000000   942990.0       4.0
# 21516  2768100206  20141001T000000   440000.0       3.0
# 21517  7904700134  20140626T000000   390000.0       3.0
# ...           ...              ...        ...       ...
# 21608   263000018  20140521T000000   360000.0       3.0
# 21609  6600060120  20150223T000000   400000.0       4.0
# 21610  1523300141  20140623T000000   402101.0       2.0
# 21611   291310100  20150116T000000   400000.0       3.0
# 21612  1523300157  20141015T000000   325000.0       2.0
#
# [100 rows x 4 columns]

# %%
# Imprime uma amostra aleatória do dataset.
dataset.sample(5)
# Out:
#                id             date     price  bedrooms
# 13546  5088500210  20150112T000000  415000.0       4.0
# 13680  8092700220  20150411T000000  280000.0       5.0
# 13352  5245600120  20141009T000000  257500.0       3.0
# 1813   5634500251  20150327T000000  450000.0       3.0
# 15595  1826049408  20150427T000000  383900.0       3.0

# %%
# Retorna em formato de tupla a quantidade de linhas e colunas do dataset.
dataset.shape
# Out:
# (21613, 4)

# %%
# Imprime informações sobre colunas e uso de memória.
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        21613 non-null  int64
#  1   date      21613 non-null  object
#  2   price     21613 non-null  float64
#  3   bedrooms  21609 non-null  float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 675.5+ KB

# %% [markdown]
# ### Analisando um Dataframe com Profiling

# %% [markdown]
# *Instalando o Pandas Profiling*

# %%
#!pip install pandas-profiling
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Using cached ydata_profiling-4.7.0-py2.py3-none-any.whl.metadata (20 kB)
# Collecting scipy<1.12,>=1.4.1 (from ydata-profiling)
#   Downloading scipy-1.11.4-cp312-cp312-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 978.4 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (2.2.1)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (3.8.3)
# Requirement already satisfied: pydantic>=2 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (2.6.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (3.1.3)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling)
#   Using cached visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2,>=1.16.0 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (4.66.2)
# Collecting seaborn<0.13,>=0.10.1 (from ydata-profiling)
#   Using cached seaborn-0.12.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (1.11.2)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.1-cp312-cp312-macosx_10_9_x86_64.whl.metadata (9.5 kB)
# Collecting typeguard<5,>=4.1.2 (from ydata-profiling)
#   Using cached typeguard-4.2.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: imagehash==4.3.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from ydata-profiling) (4.3.1)
# Collecting wordcloud>=1.9.1 (from ydata-profiling)
#   Downloading wordcloud-1.9.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Using cached dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling)
#   Downloading numba-0.59.1-cp312-cp312-macosx_10_9_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: PyWavelets in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling) (1.6.0)
# Requirement already satisfied: pillow in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.9.0.post0)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba<1,>=0.56.0->ydata-profiling)
#   Downloading llvmlite-0.42.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.2.2)
# Collecting patsy>=0.5.4 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: attrs>=19.3.0 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.2.1)
# Requirement already satisfied: six in /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages (from patsy>=0.5.4->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Using cached ydata_profiling-4.7.0-py2.py3-none-any.whl (357 kB)
# Using cached dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading numba-0.59.1-cp312-cp312-macosx_10_9_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 17.9 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.11.4-cp312-cp312-macosx_10_9_x86_64.whl (37.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.1/37.1 MB 48.1 MB/s eta 0:00:0000:0100:01
# Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Downloading statsmodels-0.14.1-cp312-cp312-macosx_10_9_x86_64.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 33.5 MB/s eta 0:00:0000:010:01
# Using cached typeguard-4.2.1-py3-none-any.whl (34 kB)
# Using cached visions-0.7.6-py3-none-any.whl (104 kB)
# Downloading wordcloud-1.9.3-cp312-cp312-macosx_10_9_x86_64.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 7.1 MB/s eta 0:00:00
# Downloading llvmlite-0.42.0-cp312-cp312-macosx_10_9_x86_64.whl (31.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.1/31.1 MB 47.0 MB/s eta 0:00:0000:0100:01
# Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: typeguard, scipy, patsy, llvmlite, dacite, numba, wordcloud, visions, statsmodels, seaborn, ydata-profiling
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.12.0
#     Uninstalling scipy-1.12.0:
#       Successfully uninstalled scipy-1.12.0
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# Successfully installed dacite-1.8.1 llvmlite-0.42.0 numba-0.59.1 patsy-0.5.6 scipy-1.11.4 seaborn-0.12.2 statsmodels-0.14.1 typeguard-4.2.1 visions-0.7.6 wordcloud-1.9.3 ydata-profiling-4.7.0

# %%
# import pandas_profiling

from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 3
#       1 # import pandas_profiling
# ----> 3 from ydata_profiling import ProfileReport
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/ydata_profiling/__init__.py:14
#      10 warnings.simplefilter("ignore", category=NumbaDeprecationWarning)
#      12 import importlib.util  # isort:skip # noqa
# ---> 14 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      15 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      16 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/ydata_profiling/compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/ydata_profiling/profile_report.py:9
#       7 with warnings.catch_warnings():
#       8     warnings.simplefilter("ignore")
# ----> 9     import pkg_resources
#      11 try:
#      12     from pyspark.sql import DataFrame as sDataFrame
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %% [markdown]
# *Lendo o arquivo de dados e construindo o dataframe chamado df*

# %%
arquivo = 'kc_house_data.csv'

# %%
df = pd.read_csv(arquivo, sep=',' ,header=0)

# %% [markdown]
# *Usando o Profiling no jupyter notebook*

# %%
pandas_profiling.ProfileReport(df, check_correlation=False)

# %% [markdown]
# * Gerando um relatorio **html**

# %%
profile = pandas_profiling.ProfileReport(df)

# %%
profile.to_file("report.html")

# %% [markdown]
# # Trabalhando com Grandes Arquivos

# %% [markdown]
# + Quando estamos trabalhando com _**Grandes Arquivos**_ temos um desafio um grande desafio que é gerenciar a memória.
# + As vezes precisamos manipular uma base de dados muito grande e por isso precisamos trabalhar com arquivos de forma diferente.
# * Uma forma é ler esses arquivos de forma limitada para não consumir toda a _**memória**_ do servidor.

# %%
arquivo = 'kc_house_data.csv'

# %%
# Lendo as 5 primeiras linhas do arquivo.
dataset = pd.read_csv(arquivo, sep=',', nrows=5)
dataset
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650       1           0     0  ...      7        1180              0
# 1      7242       2           0     0  ...      7        2170            400
# 2     10000       1           0     0  ...      6         770              0
# 3      5000       1           0     0  ...      7        1050            910
# 4      8080       1           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
dataset.head(2)

# %%
dataset = pd.read_csv(arquivo, sep=',')
dataset
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
# O parâmetro chunksize define em quantas linhas cada bloco irá conter.
chunk = pd.read_csv(arquivo, chunksize=10000)

# %%
type(chunk)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %%
# Imprimindo tamanho das partes do arquivo chunk.
for parte in chunk:
    print (len(parte))
# Out:
# 10000
# 10000
# 1613

# %%
# O parâmetro chunksize define em quantas linhas cada bloco irá conter.
chunk = pd.read_csv(arquivo, chunksize=10000)

# %%
# Interese sobre cada parte do dataframe em seguida adicione o valor processado a uma nova coluna do dataset.
lista = []
for parte in chunk:
    lista.append(parte['bedrooms'] * 2)

dataset['bedrooms_size'] = pd.concat(lista)

# %%
dataset
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# 1             2570      7242     2.0           0     0  ...        2170
# 2              770     10000     1.0           0     0  ...         770
# 3             1960      5000     1.0           0     0  ...        1050
# 4             1680      8080     1.0           0     0  ...        1680
# ...            ...       ...     ...         ...   ...  ...         ...
# 21608         1530      1131     3.0           0     0  ...        1530
# 21609         2310      5813     2.0           0     0  ...        2310
# 21610         1020      1350     2.0           0     0  ...        1020
# 21611         1600      2388     2.0           0     0  ...        1600
# 21612         1020      1076     2.0           0     0  ...        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                  0      1955             0    98178  47.5112 -122.257
# 1                400      1951          1991    98125  47.7210 -122.319
# 2                  0      1933             0    98028  47.7379 -122.233
# 3                910      1965             0    98136  47.5208 -122.393
# 4                  0      1987             0    98074  47.6168 -122.045
# ...              ...       ...           ...      ...      ...      ...
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15  bedrooms_size
# 0               1340        5650            6.0
# 1               1690        7639            6.0
# 2               2720        8062            4.0
# 3               1360        5000            8.0
# 4               1800        7503            6.0
# ...              ...         ...            ...
# 21608           1530        1509            6.0
# 21609           1830        7200            8.0
# 21610           1020        2007            4.0
# 21611           1410        1287            6.0
# 21612           1020        1357            4.0
#
# [21613 rows x 22 columns]

# %% [markdown]
# ### Mais recursos para trabalhar com grandes bases de dados

# %% [markdown]
# 1.   Tente trabalhar apenas com as colunas que você vai realmente precisar.
# 2.   Atente para o tipo de dado de cada coluna.
# 3.   Visualize qual o separador usado para separar os dados.

# %% [markdown]
# **Dica:** Se estiver no linux use o comando head para ler as 5 primeiras linhas do arquivo:
#
# `head -n 5 dataset.csv`

# %%
# !head -n 5 kc_house_data.csv
# Out:
# id,date,price,bedrooms,bathrooms,sqft_living,sqft_lot,floors,waterfront,view,condition,grade,sqft_above,sqft_basement,yr_built,yr_renovated,zipcode,lat,long,sqft_living15,sqft_lot15
# "7129300520","20141013T000000",221900,3,1,1180,5650,"1",0,0,3,7,1180,0,1955,0,"98178",47.5112,-122.257,1340,5650
# "6414100192","20141209T000000",538000,3,2.25,2570,7242,"2",0,0,3,7,2170,400,1951,1991,"98125",47.721,-122.319,1690,7639
# "5631500400","20150225T000000",180000,2,1,770,10000,"1",0,0,3,6,770,0,1933,0,"98028",47.7379,-122.233,2720,8062
# "2487200875","20141209T000000",604000,4,3,1960,5000,"1",0,0,5,7,1050,910,1965,0,"98136",47.5208,-122.393,1360,5000

# %% [markdown]
# **Dica**: Se estiver no Windows abra o prompt do **PowerShell** e use o comando abaixo:
# - gc log.txt -head 5

# %%
import pandas as pd

# %%
# Lear a base com o parâmetro nrows
df = pd.read_csv('kc_house_data.csv', sep=',', nrows=5)

# %%
df
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650       1           0     0  ...      7        1180              0
# 1      7242       2           0     0  ...      7        2170            400
# 2     10000       1           0     0  ...      6         770              0
# 3      5000       1           0     0  ...      7        1050            910
# 4      8080       1           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# *Exporte o nome das colunas para usar no parâmetro usecols*

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df = pd.read_csv("kc_house_data.csv", usecols=['id','date','price','bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront'])

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront
# 0      5650     1.0           0
# 1      7242     2.0           0
# 2     10000     1.0           0
# 3      5000     1.0           0
# 4      8080     1.0           0

# %% [markdown]
# *lendo as colunas por posições*

# %%
df = pd.read_csv("kc_house_data.csv", usecols=[0,1,2,3,4,5])

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680

# %% [markdown]
# *Ler o arquivo completo e veja o uso de memória*

# %%
df = pd.read_csv('kc_house_data.csv', sep=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           21613 non-null  int64
#  1   date         21613 non-null  object
#  2   price        21613 non-null  float64
#  3   bedrooms     21609 non-null  float64
#  4   bathrooms    21613 non-null  float64
#  5   sqft_living  21613 non-null  int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 1013.2+ KB

# %% [markdown]
# *Leia todas as colunas exceto algumas..*

# %%
data = "kc_house_data.csv"
df = pd.read_csv(data, usecols = lambda column : column not in ['sqft_living','sqft_lot','floors'])
# quero ler todas essas colunas exceto as 3 citadas

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  waterfront  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00           0
# 1  6414100192  20141209T000000  538000.0       3.0       2.25           0
# 2  5631500400  20150225T000000  180000.0       2.0       1.00           0
# 3  2487200875  20141209T000000  604000.0       4.0       3.00           0
# 4  1954400510  20150218T000000  510000.0       3.0       2.00           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98178  47.5112 -122.257           1340        5650
# 1    98125  47.7210 -122.319           1690        7639
# 2    98028  47.7379 -122.233           2720        8062
# 3    98136  47.5208 -122.393           1360        5000
# 4    98074  47.6168 -122.045           1800        7503

# %% [markdown]
# ### Trabalhe com os tipos de dados adequados

# %% [markdown]
# - Atenção para os tipos de dados **object**
# - Dados que são categóricos podem receber o tipo de dados *category*

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# *Convertendo os tipos de dados*

# %%
df.Sex = df.Sex.astype('category')
df.Embarked = df.Embarked.astype('category')
df.Survived = df.Survived.astype('category')
df.Pclass = df.Pclass.astype('category')
df.PassengerId = df.PassengerId.astype('int32')
df.Parch = df.Parch.astype('int32')
df.SibSp = df.SibSp.astype('int32')

# %% [markdown]
# *Veja o uso de memória*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int32
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int32
#  7   Parch        891 non-null    int32
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    category
# dtypes: category(4), float64(2), int32(3), object(3)
# memory usage: 49.4+ KB

# %% [markdown]
# - Quase **50%** e ganho de memória !

# %% [markdown]
# *Converta colunas em tempo de leitura*

# %%
data = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(data,  dtype = {"Embarked" : "category", "Survived": "category", "Parch": "int32"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int32
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    category
# dtypes: category(2), float64(2), int32(1), int64(3), object(4)
# memory usage: 68.1+ KB

# %% [markdown]
# # Consultando um Dataset

# %% [markdown]
# * Podemos fazer _**consultas**_ em um Dataframe, isso se assemelha a linhagem SQL.
#
# * Existem métodos interessantes para fazer consultas usando operadores lógicos (>,<,== ).
#
# * Além disso podemos fazer consultas usando instruções de agrupamento, por exemplo.
#
# * Isso da muita flexibilidade para o Cientista de dados na hora de explorar da base de dados.

# %%
# Conta a quantidade de valores únicos
import pandas as pd 
dataset = pd.read_csv('kc_house_data.csv', sep=',')
pd.value_counts(dataset['bedrooms'])
# Out:
# /var/folders/32/j5chh2bs2p91hdldnvkwbx240000gn/T/ipykernel_1545/4219598522.py:4: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(dataset['bedrooms'])
# bedrooms
# 3.0     9822
# 4.0     6881
# 2.0     2759
# 5.0     1601
# 6.0      272
# 1.0      199
# 7.0       38
# 0.0       13
# 8.0       13
# 9.0        6
# 10.0       3
# 11.0       1
# 33.0       1
# Name: count, dtype: int64

# %%
# O método loc() é usado para visualizar informações do dataset.
# Este método recebe uma lista por parâmetro e retorna o resultado da consulta.
# Consulta imóveis com 3 quartos
dataset.loc[dataset['bedrooms'] == 33]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000  640000.0      33.0       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 15870 -122.331           1330        4700
#
# [1 rows x 21 columns]

# %%
# Usando o método loc() junto com o operador &
# Consulta imóveis com 3 quartos e com o número de banheiros maior que 2
dataset.loc[(dataset['bedrooms']==3) & (dataset['bathrooms'] > 2)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0       3.0       2.25
# 6      1321400060  20140627T000000   257500.0       3.0       2.25
# 9      3793500160  20150312T000000   323000.0       3.0       2.50
# 10     1736800520  20150403T000000   662500.0       3.0       2.50
# 21     2524049179  20140826T000000  2000000.0       3.0       2.75
# ...           ...              ...        ...       ...        ...
# 21601  5100403806  20150407T000000   467000.0       3.0       2.50
# 21603  7852140040  20140825T000000   507250.0       3.0       2.50
# 21607  2997800021  20150219T000000   475000.0       3.0       2.50
# 21608   263000018  20140521T000000   360000.0       3.0       2.50
# 21611   291310100  20150116T000000   400000.0       3.0       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# 6             1715      6819     2.0           0     0  ...      7
# 9             1890      6560     2.0           0     0  ...      7
# 10            3560      9796     1.0           0     0  ...      8
# 21            3050     44867     1.0           0     4  ...      9
# ...            ...       ...     ...         ...   ...  ...    ...
# 21601         1425      1179     3.0           0     0  ...      8
# 21603         2270      5536     2.0           0     0  ...      8
# 21607         1310      1294     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
# 21611         1600      2388     2.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 1            2170            400      1951          1991    98125  47.7210
# 6            1715              0      1995             0    98003  47.3097
# 9            1890              0      2003             0    98038  47.3684
# 10           1860           1700      1965             0    98007  47.6007
# 21           2330            720      1968             0    98040  47.5316
# ...           ...            ...       ...           ...      ...      ...
# 21601        1425              0      2008             0    98125  47.6963
# 21603        2270              0      2003             0    98065  47.5389
# 21607        1180            130      2008             0    98116  47.5773
# 21608        1530              0      2009             0    98103  47.6993
# 21611        1600              0      2004             0    98027  47.5345
#
#           long  sqft_living15  sqft_lot15
# 1     -122.319           1690        7639
# 6     -122.327           2238        6819
# 9     -122.031           2390        7570
# 10    -122.145           2210        8925
# 21    -122.233           4110       20336
# ...        ...            ...         ...
# 21601 -122.318           1285        1253
# 21603 -121.881           2270        5731
# 21607 -122.409           1330        1265
# 21608 -122.346           1530        1509
# 21611 -122.069           1410        1287
#
# [4276 rows x 21 columns]

# %%
# O método sort_values() ordena o dataset pela coluna 'price' em ordem descrescente.
# Apenas o retorno da query será ordenado, não a organização do dataset.
dataset.sort_values(by='price', ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0       6.0       8.00
# 3914   9808700762  20140611T000000  7062500.0       5.0       4.50
# 9254   9208900037  20140919T000000  6885000.0       6.0       7.75
# 4411   2470100110  20140804T000000  5570000.0       5.0       5.75
# 1448   8907500070  20150413T000000  5350000.0       5.0       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0       3.0       1.00
# 16198  3028200080  20150324T000000    81000.0       2.0       1.00
# 465    8658300340  20140523T000000    80000.0       1.0       0.75
# 15293    40000362  20140506T000000    78000.0       2.0       1.00
# 1149   3421079032  20150217T000000    75000.0       1.0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# 3914         10040     37325     2.0           1     2  ...     11
# 9254          9890     31374     2.0           0     4  ...     13
# 4411          9200     35069     2.0           0     0  ...     13
# 1448          8000     23985     2.0           0     4  ...     12
# ...            ...       ...     ...         ...   ...  ...    ...
# 8274           860     10426     1.0           0     0  ...      6
# 16198          730      9975     1.0           0     0  ...      5
# 465            430      5050     1.0           0     0  ...      4
# 15293          780     16344     1.0           0     0  ...      5
# 1149           670     43377     1.0           0     0  ...      3
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 7252         8570           3480      1910          1987    98102  47.6298
# 3914         7680           2360      1940          2001    98004  47.6500
# 9254         8860           1030      2001             0    98039  47.6305
# 4411         6200           3000      2001             0    98039  47.6289
# 1448         6720           1280      2009             0    98004  47.6232
# ...           ...            ...       ...           ...      ...      ...
# 8274          860              0      1954             0    98146  47.4987
# 16198         730              0      1943             0    98168  47.4808
# 465           430              0      1912             0    98014  47.6499
# 15293         780              0      1942             0    98168  47.4739
# 1149          670              0      1966             0    98022  47.2638
#
#           long  sqft_living15  sqft_lot15
# 7252  -122.323           3940        8800
# 3914  -122.214           3930       25449
# 9254  -122.240           4540       42730
# 4411  -122.233           3560       24345
# 1448  -122.220           4600       21750
# ...        ...            ...         ...
# 8274  -122.341           1140       11250
# 16198 -122.315            860        9000
# 465   -121.909           1200        7500
# 15293 -122.280           1700       10387
# 1149  -121.906           1160       42882
#
# [21613 rows x 21 columns]

# %%
# Usando o método count() para contar o número de linhas de uma query.
dataset[dataset['bedrooms']==4].count()
# Out:
# id               6881
# date             6881
# price            6881
# bedrooms         6881
# bathrooms        6881
# sqft_living      6881
# sqft_lot         6881
# floors           6881
# waterfront       6881
# view             6881
# condition        6881
# grade            6881
# sqft_above       6881
# sqft_basement    6881
# yr_built         6881
# yr_renovated     6881
# zipcode          6881
# lat              6881
# long             6881
# sqft_living15    6881
# sqft_lot15       6881
# dtype: int64

# %% [markdown]
# # Alterando o dataset

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# Adicionando uma coluna ao Dataframe.
dataset['size'] = (dataset['bedrooms'] * 20)

# %%
# Visualizando o conteúdo da coluna criada.
dataset[['bedrooms', 'size']].head()
# Out:
#    bedrooms  size
# 0       3.0  60.0
# 1       3.0  60.0
# 2       2.0  40.0
# 3       4.0  80.0
# 4       3.0  60.0

# %%
# Criando uma função para processamento de dados.
def categoriza(s):
    if s >= 80:
        return 'Big'
    elif s >= 60:
        return 'Medium'
    elif s >= 40:
        return 'Small'

# %%
# Criando uma nova coluna a partir do processamento realizado.
dataset['cat_size'] = dataset['size'].apply(categoriza)

# %%
# Visualizando a nova coluna criada.
dataset['cat_size'].head()
# Out:
# 0    Medium
# 1    Medium
# 2     Small
# 3       Big
# 4    Medium
# Name: cat_size, dtype: object

# %%
# Ver a distribuicao da coluna com o método value_counts.
pd.value_counts(dataset['cat_size'])
# Out:
# /var/folders/32/j5chh2bs2p91hdldnvkwbx240000gn/T/ipykernel_1545/1490034380.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(dataset['cat_size'])
# cat_size
# Medium    9822
# Big       8816
# Small     2759
# Name: count, dtype: int64

# %%
# O método drop é usado para excluir dados no dataframe.
# A opção axis=1 define que queremos excluir uma coluna e não uma linha.
# O parâmetro inplace define que a alteração irá modificar o objeto em memória.

dataset.drop(['cat_size'], axis=1, inplace=True)

# %%
# Apagando a coluna 'size'
dataset.drop(['size'], axis=1, inplace=True)

# %%
# Visualizando o dataset.
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# **Apagando linhas baseado em Condições lógicas!**

# %%
# Dropa linhas com bedrooms = 0
dataset.drop(dataset[dataset.bedrooms==0].index ,inplace=True)

# %%
# Dropa linhas maiores que 30
dataset.drop(dataset[dataset.bedrooms>30].index ,inplace=True)

# %%
#pd.value_counts(dataset['bedrooms'])
dataset['bedrooms'].value_counts()
# Out:
# bedrooms
# 3.0     9822
# 4.0     6881
# 2.0     2759
# 5.0     1601
# 6.0      272
# 1.0      199
# 7.0       38
# 8.0       13
# 9.0        6
# 10.0       3
# 11.0       1
# Name: count, dtype: int64

# %% [markdown]
# **Percorrendo linhas de um Dataframe Pandas**

# %% [markdown]
# - Método iterrows() permite percorrer por todas as linhas de um dataframe.
# - Esse método retorna um objeto **iterator** que contém o indice de cada linha e um cada linha em um dado do tipo série.

# %%
type(dataset.iterrows())
# Out:
# generator

# %%
# Imprime a primeira linha do objeto iterator
next(dataset.iterrows())
# Out:
# (0,
#  id                    7129300520
#  date             20141013T000000
#  price                   221900.0
#  bedrooms                     3.0
#  bathrooms                    1.0
#  sqft_living                 1180
#  sqft_lot                    5650
#  floors                       1.0
#  waterfront                     0
#  view                           0
#  condition                      3
#  grade                          7
#  sqft_above                  1180
#  sqft_basement                  0
#  yr_built                    1955
#  yr_renovated                   0
#  zipcode                    98178
#  lat                      47.5112
#  long                    -122.257
#  sqft_living15               1340
#  sqft_lot15                  5650
#  Name: 0, dtype: object)

# %%
# Percorrendo o dataframe e imprimindo o indice e cada linha.
for indice, linha in dataset.head(10).iterrows():
     print(indice, linha)
# Out:
# 0 id                    7129300520
# date             20141013T000000
# price                   221900.0
# bedrooms                     3.0
# bathrooms                    1.0
# sqft_living                 1180
# sqft_lot                    5650
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1180
# sqft_basement                  0
# yr_built                    1955
# yr_renovated                   0
# zipcode                    98178
# lat                      47.5112
# long                    -122.257
# sqft_living15               1340
# sqft_lot15                  5650
# Name: 0, dtype: object
# 1 id                    6414100192
# date             20141209T000000
# price                   538000.0
# bedrooms                     3.0
# bathrooms                   2.25
# sqft_living                 2570
# sqft_lot                    7242
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  2170
# sqft_basement                400
# yr_built                    1951
# yr_renovated                1991
# zipcode                    98125
# lat                       47.721
# long                    -122.319
# sqft_living15               1690
# sqft_lot15                  7639
# Name: 1, dtype: object
# 2 id                    5631500400
# date             20150225T000000
# price                   180000.0
# bedrooms                     2.0
# bathrooms                    1.0
# sqft_living                  770
# sqft_lot                   10000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          6
# sqft_above                   770
# sqft_basement                  0
# yr_built                    1933
# yr_renovated                   0
# zipcode                    98028
# lat                      47.7379
# long                    -122.233
# sqft_living15               2720
# sqft_lot15                  8062
# Name: 2, dtype: object
# 3 id                    2487200875
# date             20141209T000000
# price                   604000.0
# bedrooms                     4.0
# bathrooms                    3.0
# sqft_living                 1960
# sqft_lot                    5000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      5
# grade                          7
# sqft_above                  1050
# sqft_basement                910
# yr_built                    1965
# yr_renovated                   0
# zipcode                    98136
# lat                      47.5208
# long                    -122.393
# sqft_living15               1360
# sqft_lot15                  5000
# Name: 3, dtype: object
# 4 id                    1954400510
# date             20150218T000000
# price                   510000.0
# bedrooms                     3.0
# bathrooms                    2.0
# sqft_living                 1680
# sqft_lot                    8080
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  1680
# sqft_basement                  0
# yr_built                    1987
# yr_renovated                   0
# zipcode                    98074
# lat                      47.6168
# long                    -122.045
# sqft_living15               1800
# sqft_lot15                  7503
# Name: 4, dtype: object
# 5 id                    7237550310
# date             20140512T000000
# price                  1225000.0
# bedrooms                     4.0
# bathrooms                    4.5
# sqft_living                 5420
# sqft_lot                  101930
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                         11
# sqft_above                  3890
# sqft_basement               1530
# yr_built                    2001
# yr_renovated                   0
# zipcode                    98053
# lat                      47.6561
# long                    -122.005
# sqft_living15               4760
# sqft_lot15                101930
# Name: 5, dtype: object
# 6 id                    1321400060
# date             20140627T000000
# price                   257500.0
# bedrooms                     3.0
# bathrooms                   2.25
# sqft_living                 1715
# sqft_lot                    6819
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1715
# sqft_basement                  0
# yr_built                    1995
# yr_renovated                   0
# zipcode                    98003
# lat                      47.3097
# long                    -122.327
# sqft_living15               2238
# sqft_lot15                  6819
# Name: 6, dtype: object
# 7 id                    2008000270
# date             20150115T000000
# price                   291850.0
# bedrooms                     3.0
# bathrooms                    1.5
# sqft_living                 1060
# sqft_lot                    9711
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1060
# sqft_basement                  0
# yr_built                    1963
# yr_renovated                   0
# zipcode                    98198
# lat                      47.4095
# long                    -122.315
# sqft_living15               1650
# sqft_lot15                  9711
# Name: 7, dtype: object
# 8 id                    2414600126
# date             20150415T000000
# price                   229500.0
# bedrooms                     3.0
# bathrooms                    1.0
# sqft_living                 1780
# sqft_lot                    7470
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1050
# sqft_basement                730
# yr_built                    1960
# yr_renovated                   0
# zipcode                    98146
# lat                      47.5123
# long                    -122.337
# sqft_living15               1780
# sqft_lot15                  8113
# Name: 8, dtype: object
# 9 id                    3793500160
# date             20150312T000000
# price                   323000.0
# bedrooms                     3.0
# bathrooms                    2.5
# sqft_living                 1890
# sqft_lot                    6560
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1890
# sqft_basement                  0
# yr_built                    2003
# yr_renovated                   0
# zipcode                    98038
# lat                      47.3684
# long                    -122.031
# sqft_living15               2390
# sqft_lot15                  7570
# Name: 9, dtype: object

# %%
# Percorrendo o dataframe e acessando colunas nomes.
for indice, linha in dataset.head(10).iterrows():
     print(indice, linha['bedrooms'], linha['floors'], linha['price'])
# Out:
# 0 3.0 1.0 221900.0
# 1 3.0 2.0 538000.0
# 2 2.0 1.0 180000.0
# 3 4.0 1.0 604000.0
# 4 3.0 1.0 510000.0
# 5 4.0 1.0 1225000.0
# 6 3.0 2.0 257500.0
# 7 3.0 1.0 291850.0
# 8 3.0 1.0 229500.0
# 9 3.0 2.0 323000.0

# %% [markdown]
# **Atualizando Dataframe ao percorrer linha a linha**

# %%
# Imprime os 5 primeiros valores de preços antes da atualização.
dataset.price.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
# Percorrendo e atualizando linhas de um dataframe.
# Atualiza o valor da coluna PRICE multiplicando seu valor por 2.
# é preciso usar o método at()
for indice, linha in dataset.iterrows():
    dataset.at[indice , 'price'] = linha['price'] * 2

# %%
dataset.price.head()
# Out:
# 0     443800.0
# 1    1076000.0
# 2     360000.0
# 3    1208000.0
# 4    1020000.0
# Name: price, dtype: float64

# %% [markdown]
# **Percorrendo um dataframe com o método itertuples()**

# %% [markdown]
# - Retorna as linhas e índice em formato de tuplas.
# - Costuma ser mais rápido que o iterrows()

# %%
# Percorre o dataframe usando itertuples()
for linha in dataset.head().itertuples():
    print(linha)
# Out:
# Pandas(Index=0, id=7129300520, date='20141013T000000', price=443800.0, bedrooms=3.0, bathrooms=1.0, sqft_living=1180, sqft_lot=5650, floors=1.0, waterfront=0, view=0, condition=3, grade=7, sqft_above=1180, sqft_basement=0, yr_built=1955, yr_renovated=0, zipcode=98178, lat=47.5112, long=-122.257, sqft_living15=1340, sqft_lot15=5650)
# Pandas(Index=1, id=6414100192, date='20141209T000000', price=1076000.0, bedrooms=3.0, bathrooms=2.25, sqft_living=2570, sqft_lot=7242, floors=2.0, waterfront=0, view=0, condition=3, grade=7, sqft_above=2170, sqft_basement=400, yr_built=1951, yr_renovated=1991, zipcode=98125, lat=47.721, long=-122.319, sqft_living15=1690, sqft_lot15=7639)
# Pandas(Index=2, id=5631500400, date='20150225T000000', price=360000.0, bedrooms=2.0, bathrooms=1.0, sqft_living=770, sqft_lot=10000, floors=1.0, waterfront=0, view=0, condition=3, grade=6, sqft_above=770, sqft_basement=0, yr_built=1933, yr_renovated=0, zipcode=98028, lat=47.7379, long=-122.233, sqft_living15=2720, sqft_lot15=8062)
# Pandas(Index=3, id=2487200875, date='20141209T000000', price=1208000.0, bedrooms=4.0, bathrooms=3.0, sqft_living=1960, sqft_lot=5000, floors=1.0, waterfront=0, view=0, condition=5, grade=7, sqft_above=1050, sqft_basement=910, yr_built=1965, yr_renovated=0, zipcode=98136, lat=47.5208, long=-122.393, sqft_living15=1360, sqft_lot15=5000)
# Pandas(Index=4, id=1954400510, date='20150218T000000', price=1020000.0, bedrooms=3.0, bathrooms=2.0, sqft_living=1680, sqft_lot=8080, floors=1.0, waterfront=0, view=0, condition=3, grade=8, sqft_above=1680, sqft_basement=0, yr_built=1987, yr_renovated=0, zipcode=98074, lat=47.6168, long=-122.045, sqft_living15=1800, sqft_lot15=7503)

# %%
# Imprime linhas chamando as colunas por nome.
for linha in dataset.head().itertuples():
    print(linha.id, linha.bedrooms, linha.price)
# Out:
# 7129300520 3.0 443800.0
# 6414100192 3.0 1076000.0
# 5631500400 2.0 360000.0
# 2487200875 4.0 1208000.0
# 1954400510 3.0 1020000.0

# %%
for indice, linha in dataset.itertuples():
    dataset.at[indice , 'price'] = linha['price'] * 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 for indice, linha in dataset.itertuples():
#       2     dataset.at[indice , 'price'] = linha['price'] * 2
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # Missing Values

# %% [markdown]
# * **Missing Values** são valores faltantes em colunas, esses podem ser oriundos de falhas em cargas de dados, falhas em crawlers ou até mesmo corrupção de dados.
#
# * Missing Values podem ser um problema em várias situações, como por exemplo, algoritmos de machine learning que não trabalham bem com dados faltantes.
#
# * Estes também podem atrapalhar resultados de análises.
#
# * Vamos aprender como encontrar missing values na base de dados e como manipular esses valores.

# %%
arquivo = 'kc_house_data.csv'
dataset = pd.read_csv(arquivo, sep=',', header=0)
dataset.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# Consultando linhas com valores faltantes.
dataset.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#Com este comando removemos todas as linhas onde tenha pela menos um registro faltante em algum atributo.
dataset.dropna(inplace=True)

# %%
# É possível ainda, remover somente linhas que estejam com valores faltantes em todas as colunas, veja:
dataset.dropna(how='all', inplace=True)

# %%
#preenche com a media dos valores da coluns floors os values null
# interessante quando tivermos muitos valores faltantes no qual vai deixar a base desbalanceada
dataset['floors'].fillna(dataset['floors'].mean(), inplace=True)

# %%
#preenche com 1 os values null da coluna bedrooms
dataset['bedrooms'].fillna(1, inplace=True)

# %% [markdown]
# # Visualização de dados

# %%
# Plota em um gŕafico de barras o preço dos imóveis

import matplotlib as plt

# %matplotlib inline
dataset['price'].plot()
# Out:
# <Axes: >

# %%
# Plota em gráfico de dispersão o preço e o numero de quartos de imóveis
dataset.plot(x='bedrooms',y='price',kind='scatter', title='Bedrooms x Price',color='r')
# Out:
# <Axes: title={'center': 'Bedrooms x Price'}, xlabel='bedrooms', ylabel='price'>

# %%
# Plota em gráfico de dispersão o preço e o número de banheiros
dataset.plot(x='bathrooms',y='price',kind='scatter',color='y')
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>
