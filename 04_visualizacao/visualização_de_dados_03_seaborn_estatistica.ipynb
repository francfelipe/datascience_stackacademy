# %% [markdown]
# # Minerando Dados  - ** Visualização de Dados **

# %% [markdown]
# **Trabalhando com Seaborn**

# %% [markdown]
# * Biblioteca para visualização de dados baseado em Matplotlib.
# * Interface de alto nível para gráficos estatísticos.
# * Fornece uma interface atraente e profissional para os gráficos.
# * Simples e muito intuitiva de usar.

# %% [markdown]
# **Quando utilizar?**
#
# * Útil para análise e exploração de dados.
# * Apresentar análises visuais.

# %% [markdown]
# ## Carregando Dataset

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %% [markdown]
# ## Plotando dados categóricos

# %% [markdown]
# * Quando trabalhamos com variáveis categóricas temos que visualizar dados de formas diferentes.
# * O Seaborn fornece o método catplot() que já contém diversos tipos de gráficos embutidos.
# * Isso facilita, pois, você pode usar diferentes gráficos usando um mesmo método.

# %% [markdown]
# **Gráficos de barras ou também conhecidos como gráficos de colunas**

# %%
sns.catplot(x="sex", kind="count", palette="Set2", data=tips);
# Out:
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ** Gráfico de barras horizontais usando a coluna *day* **

# %%
sns.catplot(y="day", kind="count", palette="Set1", data=tips);
# Out:
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# **Scatter plot com dados categóricos**

# %%
sns.catplot(x="day", y="total_bill", palette="Set2", data=tips);
# Out:
# /var/folders/32/j5chh2bs2p91hdldnvkwbx240000gn/T/ipykernel_5714/462313445.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x="day", y="total_bill", palette="Set2", data=tips);
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.catplot(x="day", y="total_bill", palette="Set2", data=tips);
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3098, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3095     plot_kws.setdefault("s", plot_kws.pop("size", 5) ** 2)
#    3096     plot_kws.setdefault("linewidth", 0)
# -> 3098     p.plot_strips(
#    3099         jitter=jitter,
#    3100         dodge=dodge,
#    3101         color=color,
#    3102         edgecolor=edgecolor,
#    3103         plot_kws=plot_kws,
#    3104     )
#    3106 elif kind == "swarm":
#    3107
#    3108     # TODO get these defaults programmatically?
#    3109     dodge = kwargs.pop("dodge", False)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:264, in _CategoricalPlotterNew.plot_strips(self, jitter, dodge, color, edgecolor, plot_kws)
#     255 def plot_strips(
#     256     self,
#     257     jitter,
#    (...)
#     261     plot_kws,
#     262 ):
# --> 264     width = .8 * self._native_width
#     265     offsets = self._nested_offsets(width, dodge)
#     267     if jitter is True:
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:229, in _CategoricalPlotterNew._native_width(self)
#     226 @property
#     227 def _native_width(self):
#     228     """Return unit of width separating categories on native numeric scale."""
# --> 229     unique_values = np.unique(self.comp_data[self.cat_axis])
#     230     if len(unique_values) > 1:
#     231         native_width = np.nanmin(np.diff(unique_values))
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119, in VectorPlotter.comp_data(self)
#    1117 grouped = self.plot_data[var].groupby(self.converters[var], sort=False)
#    1118 for converter, orig in grouped:
# -> 1119     with pd.option_context('mode.use_inf_as_null', True):
#    1120         orig = orig.dropna()
#    1121         if var in self.var_levels:
#    1122             # TODO this should happen in some centralized location
#    1123             # it is similar to GH2419, but more complicated because
#    1124             # supporting `order` in categorical plots is tricky
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:480, in option_context.__enter__(self)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#     149     root, k = _get_root(key)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:132, in _get_single_key(pat, silent)
#     130     if not silent:
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#     134     raise OptionError("Pattern matched multiple keys")
#
# OptionError: No such keys(s): 'mode.use_inf_as_null'

# %% [markdown]
# **O parâmetro swarm evita sobreposição de pontos**

# %%
sns.catplot(x="day", y="total_bill", kind='swarm', data=tips);
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.catplot(x="day", y="total_bill", kind='swarm', data=tips);
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3122, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3119     if plot_kws.setdefault("linewidth", 0) is None:
#    3120         plot_kws["linewidth"] = np.sqrt(plot_kws["s"]) / 10
# -> 3122     p.plot_swarms(
#    3123         dodge=dodge,
#    3124         color=color,
#    3125         edgecolor=edgecolor,
#    3126         warn_thresh=warn_thresh,
#    3127         plot_kws=plot_kws,
#    3128     )
#    3130 # XXX best way to do this housekeeping?
#    3131 for ax in g.axes.flat:
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:330, in _CategoricalPlotterNew.plot_swarms(self, dodge, color, edgecolor, warn_thresh, plot_kws)
#     321 def plot_swarms(
#     322     self,
#     323     dodge,
#    (...)
#     327     plot_kws,
#     328 ):
# --> 330     width = .8 * self._native_width
#     331     offsets = self._nested_offsets(width, dodge)
#     333     iter_vars = [self.cat_axis]
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:229, in _CategoricalPlotterNew._native_width(self)
#     226 @property
#     227 def _native_width(self):
#     228     """Return unit of width separating categories on native numeric scale."""
# --> 229     unique_values = np.unique(self.comp_data[self.cat_axis])
#     230     if len(unique_values) > 1:
#     231         native_width = np.nanmin(np.diff(unique_values))
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119, in VectorPlotter.comp_data(self)
#    1117 grouped = self.plot_data[var].groupby(self.converters[var], sort=False)
#    1118 for converter, orig in grouped:
# -> 1119     with pd.option_context('mode.use_inf_as_null', True):
#    1120         orig = orig.dropna()
#    1121         if var in self.var_levels:
#    1122             # TODO this should happen in some centralized location
#    1123             # it is similar to GH2419, but more complicated because
#    1124             # supporting `order` in categorical plots is tricky
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:480, in option_context.__enter__(self)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#     149     root, k = _get_root(key)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:132, in _get_single_key(pat, silent)
#     130     if not silent:
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#     134     raise OptionError("Pattern matched multiple keys")
#
# OptionError: No such keys(s): 'mode.use_inf_as_null'

# %% [markdown]
# **O parâmetro hue permite adicionarmos uma terceira variável a nossa visualização**

# %%
sns.catplot(x="day", y="total_bill", kind='swarm', hue="sex", palette="Dark2", data=tips);

# %% [markdown]
# * O parametro **order** permite alterarmos a ordem padrão das categorias que estão sendo exibidas.
#
# * Isso é útil quando temos mais um gráfico na mesma figura e queremos manter as mesmas ordens.

# %%
sns.catplot(x="day", y="total_bill", kind='swarm', hue="sex", order=['Sat','Sun','Fri','Thur'], data=tips);
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.catplot(x="day", y="total_bill", kind='swarm', hue="sex", order=['Sat','Sun','Fri','Thur'], data=tips);
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3122, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3119     if plot_kws.setdefault("linewidth", 0) is None:
#    3120         plot_kws["linewidth"] = np.sqrt(plot_kws["s"]) / 10
# -> 3122     p.plot_swarms(
#    3123         dodge=dodge,
#    3124         color=color,
#    3125         edgecolor=edgecolor,
#    3126         warn_thresh=warn_thresh,
#    3127         plot_kws=plot_kws,
#    3128     )
#    3130 # XXX best way to do this housekeeping?
#    3131 for ax in g.axes.flat:
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:330, in _CategoricalPlotterNew.plot_swarms(self, dodge, color, edgecolor, warn_thresh, plot_kws)
#     321 def plot_swarms(
#     322     self,
#     323     dodge,
#    (...)
#     327     plot_kws,
#     328 ):
# --> 330     width = .8 * self._native_width
#     331     offsets = self._nested_offsets(width, dodge)
#     333     iter_vars = [self.cat_axis]
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:229, in _CategoricalPlotterNew._native_width(self)
#     226 @property
#     227 def _native_width(self):
#     228     """Return unit of width separating categories on native numeric scale."""
# --> 229     unique_values = np.unique(self.comp_data[self.cat_axis])
#     230     if len(unique_values) > 1:
#     231         native_width = np.nanmin(np.diff(unique_values))
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119, in VectorPlotter.comp_data(self)
#    1117 grouped = self.plot_data[var].groupby(self.converters[var], sort=False)
#    1118 for converter, orig in grouped:
# -> 1119     with pd.option_context('mode.use_inf_as_null', True):
#    1120         orig = orig.dropna()
#    1121         if var in self.var_levels:
#    1122             # TODO this should happen in some centralized location
#    1123             # it is similar to GH2419, but more complicated because
#    1124             # supporting `order` in categorical plots is tricky
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:480, in option_context.__enter__(self)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#     149     root, k = _get_root(key)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:132, in _get_single_key(pat, silent)
#     130     if not silent:
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#     134     raise OptionError("Pattern matched multiple keys")
#
# OptionError: No such keys(s): 'mode.use_inf_as_null'

# %% [markdown]
# **Invertendo a visualização para plots horizontais**

# %%
sns.catplot(x="total_bill", y="day", kind="swarm", data=tips);
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.catplot(x="total_bill", y="day", kind="swarm", data=tips);
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3122, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3119     if plot_kws.setdefault("linewidth", 0) is None:
#    3120         plot_kws["linewidth"] = np.sqrt(plot_kws["s"]) / 10
# -> 3122     p.plot_swarms(
#    3123         dodge=dodge,
#    3124         color=color,
#    3125         edgecolor=edgecolor,
#    3126         warn_thresh=warn_thresh,
#    3127         plot_kws=plot_kws,
#    3128     )
#    3130 # XXX best way to do this housekeeping?
#    3131 for ax in g.axes.flat:
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:330, in _CategoricalPlotterNew.plot_swarms(self, dodge, color, edgecolor, warn_thresh, plot_kws)
#     321 def plot_swarms(
#     322     self,
#     323     dodge,
#    (...)
#     327     plot_kws,
#     328 ):
# --> 330     width = .8 * self._native_width
#     331     offsets = self._nested_offsets(width, dodge)
#     333     iter_vars = [self.cat_axis]
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:229, in _CategoricalPlotterNew._native_width(self)
#     226 @property
#     227 def _native_width(self):
#     228     """Return unit of width separating categories on native numeric scale."""
# --> 229     unique_values = np.unique(self.comp_data[self.cat_axis])
#     230     if len(unique_values) > 1:
#     231         native_width = np.nanmin(np.diff(unique_values))
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119, in VectorPlotter.comp_data(self)
#    1117 grouped = self.plot_data[var].groupby(self.converters[var], sort=False)
#    1118 for converter, orig in grouped:
# -> 1119     with pd.option_context('mode.use_inf_as_null', True):
#    1120         orig = orig.dropna()
#    1121         if var in self.var_levels:
#    1122             # TODO this should happen in some centralized location
#    1123             # it is similar to GH2419, but more complicated because
#    1124             # supporting `order` in categorical plots is tricky
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:480, in option_context.__enter__(self)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#     149     root, k = _get_root(key)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:132, in _get_single_key(pat, silent)
#     130     if not silent:
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#     134     raise OptionError("Pattern matched multiple keys")
#
# OptionError: No such keys(s): 'mode.use_inf_as_null'

# %% [markdown]
# ## Gráficos com Regressão

# %% [markdown]
# * Quando temos muitas variáveis quantitativas em nossos dados é interessante visualizar como estas se relacionam.
# * Podemos visualizar essas informações com linhas de regressão.
# * Com modelos de regressão simples é possível checar se existe alguma **correlacão** entre algumas variáveis.

# %%
import seaborn as sns
tips = sns.load_dataset("tips")

# %% [markdown]
# **Exibe a linha de regressão para visualizar correladdção entre as variáveis**

# %%
# %matplotlib inline
sns.lmplot(x="total_bill", y="tip", hue="sex", palette="Pastel1", data=tips);

# %% [markdown]
# ** Usando o parâmetro col para segregar os gráficos pelo valor da coluna categórica *time* **

# %%
# %matplotlib inline
sns.lmplot(x="total_bill",y="tip", hue="smoker", col="time", palette="Set2", data=tips);

# %% [markdown]
# **Parâmetros scatter_kws e line_kws**

# %%
# %matplotlib inline
sns.lmplot(x="total_bill",
           y="tip", 
           hue="smoker", 
           col="time", 
           palette="Set1",
           data=tips, 
           scatter_kws={'s': 90, 'alpha': 0.5},
           line_kws={'lw': 4});

# %% [markdown]
# ** Segregando gráficos pelo parâmetro *col* e pelo parâmetro *row* **

# %%
# %matplotlib inline
sns.lmplot(x="total_bill", y="tip", hue="smoker",col="time", row="sex", palette="Set2", data=tips);

# %% [markdown]
# ## Visualizando distribuição de observações

# %% [markdown]
# * Um dataset muito grande será difícil de visualizar variáveis categóricas.
# * É preciso sumarizar a distribuição dos dados para facilitar a visualização.
# * Podemos usar um gráfico do tipo Boxplot para visualizar a distribuição de tais variáveis.
# * Esse tipo de gráfico é muito útil para visualizar ***Outliers***.

# %% [markdown]
# ** Boxplot de Dias da semana por total de conta**

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=tips);
# Out:
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ** Gráfico de Boxplot dos dias por total de conta e se a pessoa é fumante ou não.**

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips);
# Out:
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# * Tipo de Boxplot com foco maior na forma dos dados do que nos outliers.
# * Esse tipo de gráfico é interessante quando temos grandes datasets.

# %%
sns.catplot(x="day", y="total_bill", kind="boxen", data=tips);
# Out:
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.catplot(x="day", y="total_bill", kind="boxen", data=tips);
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3240, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3237 g = FacetGrid(**facet_kws)
#    3239 # Draw the plot onto the facets
# -> 3240 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3242 if p.orient == "h":
#    3243     g.set_axis_labels(p.value_label, p.group_label)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:819, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     816     kwargs["data"] = data_ijk
#     818     # Draw the plot
# --> 819     self._facet_plot(func, ax, args, kwargs)
#     821 # For axis labels, prefer to use positional args for backcompat
#     822 # but also extract the x/y kwargs and use if no corresponding arg
#     823 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# --> 848 func(*plot_args, **plot_kwargs)
#     850 # Sort out the supporting information
#     851 self._update_legend_data(ax)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:2414, in boxenplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, k_depth, linewidth, scale, outlier_prop, trust_alpha, showfliers, ax, box_kws, flier_kws, line_kws)
#    2411 if ax is None:
#    2412     ax = plt.gca()
# -> 2414 plotter.plot(ax, box_kws, flier_kws, line_kws)
#    2415 return ax
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:2044, in _LVPlotter.plot(self, ax, box_kws, flier_kws, line_kws)
#    2042 def plot(self, ax, box_kws, flier_kws, line_kws):
#    2043     """Make the plot."""
# -> 2044     self.draw_letter_value_plot(ax, box_kws, flier_kws, line_kws)
#    2045     self.annotate_axes(ax)
#    2046     if self.orient == "h":
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:1999, in _LVPlotter.draw_letter_value_plot(self, ax, box_kws, flier_kws, line_kws)
#    1995         continue
#    1997     color = self.colors[i]
# -> 1999     self._lvplot(box_data,
#    2000                  positions=[i],
#    2001                  color=color,
#    2002                  widths=self.width,
#    2003                  ax=ax,
#    2004                  box_kws=box_kws,
#    2005                  flier_kws=flier_kws,
#    2006                  line_kws=line_kws)
#    2008 else:
#    2009     # Draw nested groups of boxes
#    2010     offsets = self.hue_offsets
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:1892, in _LVPlotter._lvplot(self, box_data, positions, color, widths, ax, box_kws, flier_kws, line_kws)
#    1888     ax.plot(xx, yy, **line_kws)
#    1889 else:
#    1890     # Get the number of data points and calculate "depth" of
#    1891     # letter-value plot
# -> 1892     box_ends, k = self._lv_box_ends(box_data)
#    1894     # Anonymous functions for calculating the width and height
#    1895     # of the letter value boxes
#    1896     width = self._width_functions(self.scale)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:1793, in _LVPlotter._lv_box_ends(self, vals)
#    1790 vals = np.asarray(vals)
#    1791 # Remove infinite values while handling a 'object' dtype
#    1792 # that can come from pd.Float64Dtype() input
# -> 1793 with pd.option_context('mode.use_inf_as_null', True):
#    1794     vals = vals[~pd.isnull(vals)]
#    1795 n = len(vals)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:480, in option_context.__enter__(self)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#     149     root, k = _get_root(key)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:132, in _get_single_key(pat, silent)
#     130     if not silent:
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#     134     raise OptionError("Pattern matched multiple keys")
#
# OptionError: No such keys(s): 'mode.use_inf_as_null'

# %% [markdown]
# * O Método stripplot permite plotar a distribuição dos dados.
# * Podemos combinar os dois gráficos para ter mais informação.

# %%
sns.catplot(x="day", y="total_bill", kind="boxen", data=tips);
sns.stripplot(x="day", y="total_bill", data=tips, color="blue");
# Out:
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.catplot(x="day", y="total_bill", kind="boxen", data=tips);
#       2 sns.stripplot(x="day", y="total_bill", data=tips, color="blue");
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3240, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3237 g = FacetGrid(**facet_kws)
#    3239 # Draw the plot onto the facets
# -> 3240 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3242 if p.orient == "h":
#    3243     g.set_axis_labels(p.value_label, p.group_label)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:819, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     816     kwargs["data"] = data_ijk
#     818     # Draw the plot
# --> 819     self._facet_plot(func, ax, args, kwargs)
#     821 # For axis labels, prefer to use positional args for backcompat
#     822 # but also extract the x/y kwargs and use if no corresponding arg
#     823 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# --> 848 func(*plot_args, **plot_kwargs)
#     850 # Sort out the supporting information
#     851 self._update_legend_data(ax)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:2414, in boxenplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, k_depth, linewidth, scale, outlier_prop, trust_alpha, showfliers, ax, box_kws, flier_kws, line_kws)
#    2411 if ax is None:
#    2412     ax = plt.gca()
# -> 2414 plotter.plot(ax, box_kws, flier_kws, line_kws)
#    2415 return ax
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:2044, in _LVPlotter.plot(self, ax, box_kws, flier_kws, line_kws)
#    2042 def plot(self, ax, box_kws, flier_kws, line_kws):
#    2043     """Make the plot."""
# -> 2044     self.draw_letter_value_plot(ax, box_kws, flier_kws, line_kws)
#    2045     self.annotate_axes(ax)
#    2046     if self.orient == "h":
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:1999, in _LVPlotter.draw_letter_value_plot(self, ax, box_kws, flier_kws, line_kws)
#    1995         continue
#    1997     color = self.colors[i]
# -> 1999     self._lvplot(box_data,
#    2000                  positions=[i],
#    2001                  color=color,
#    2002                  widths=self.width,
#    2003                  ax=ax,
#    2004                  box_kws=box_kws,
#    2005                  flier_kws=flier_kws,
#    2006                  line_kws=line_kws)
#    2008 else:
#    2009     # Draw nested groups of boxes
#    2010     offsets = self.hue_offsets
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:1892, in _LVPlotter._lvplot(self, box_data, positions, color, widths, ax, box_kws, flier_kws, line_kws)
#    1888     ax.plot(xx, yy, **line_kws)
#    1889 else:
#    1890     # Get the number of data points and calculate "depth" of
#    1891     # letter-value plot
# -> 1892     box_ends, k = self._lv_box_ends(box_data)
#    1894     # Anonymous functions for calculating the width and height
#    1895     # of the letter value boxes
#    1896     width = self._width_functions(self.scale)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:1793, in _LVPlotter._lv_box_ends(self, vals)
#    1790 vals = np.asarray(vals)
#    1791 # Remove infinite values while handling a 'object' dtype
#    1792 # that can come from pd.Float64Dtype() input
# -> 1793 with pd.option_context('mode.use_inf_as_null', True):
#    1794     vals = vals[~pd.isnull(vals)]
#    1795 n = len(vals)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:480, in option_context.__enter__(self)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#     149     root, k = _get_root(key)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:132, in _get_single_key(pat, silent)
#     130     if not silent:
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#     134     raise OptionError("Pattern matched multiple keys")
#
# OptionError: No such keys(s): 'mode.use_inf_as_null'

# %% [markdown]
# **O método catplot() permite usarmos facetgrid assim podemos combinar gráficos em uma única figura**

# %%
# %matplotlib inline
sns.catplot(x="sex", y="total_bill", hue="smoker", col="time", data=tips, kind="boxen",height=4);
# Out:
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[18], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 sns.catplot(x="sex", y="total_bill", hue="smoker", col="time", data=tips, kind="boxen",height=4);
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3240, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3237 g = FacetGrid(**facet_kws)
#    3239 # Draw the plot onto the facets
# -> 3240 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3242 if p.orient == "h":
#    3243     g.set_axis_labels(p.value_label, p.group_label)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:819, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     816     kwargs["data"] = data_ijk
#     818     # Draw the plot
# --> 819     self._facet_plot(func, ax, args, kwargs)
#     821 # For axis labels, prefer to use positional args for backcompat
#     822 # but also extract the x/y kwargs and use if no corresponding arg
#     823 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# --> 848 func(*plot_args, **plot_kwargs)
#     850 # Sort out the supporting information
#     851 self._update_legend_data(ax)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:2414, in boxenplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, k_depth, linewidth, scale, outlier_prop, trust_alpha, showfliers, ax, box_kws, flier_kws, line_kws)
#    2411 if ax is None:
#    2412     ax = plt.gca()
# -> 2414 plotter.plot(ax, box_kws, flier_kws, line_kws)
#    2415 return ax
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:2044, in _LVPlotter.plot(self, ax, box_kws, flier_kws, line_kws)
#    2042 def plot(self, ax, box_kws, flier_kws, line_kws):
#    2043     """Make the plot."""
# -> 2044     self.draw_letter_value_plot(ax, box_kws, flier_kws, line_kws)
#    2045     self.annotate_axes(ax)
#    2046     if self.orient == "h":
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:2030, in _LVPlotter.draw_letter_value_plot(self, ax, box_kws, flier_kws, line_kws)
#    2028             color = self.colors[j]
#    2029             center = i + offsets[j]
# -> 2030             self._lvplot(box_data,
#    2031                          positions=[center],
#    2032                          color=color,
#    2033                          widths=self.nested_width,
#    2034                          ax=ax,
#    2035                          box_kws=box_kws,
#    2036                          flier_kws=flier_kws,
#    2037                          line_kws=line_kws)
#    2039 # Autoscale the values axis to make sure all patches are visible
#    2040 ax.autoscale_view(scalex=self.orient == "h", scaley=self.orient == "v")
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:1892, in _LVPlotter._lvplot(self, box_data, positions, color, widths, ax, box_kws, flier_kws, line_kws)
#    1888     ax.plot(xx, yy, **line_kws)
#    1889 else:
#    1890     # Get the number of data points and calculate "depth" of
#    1891     # letter-value plot
# -> 1892     box_ends, k = self._lv_box_ends(box_data)
#    1894     # Anonymous functions for calculating the width and height
#    1895     # of the letter value boxes
#    1896     width = self._width_functions(self.scale)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:1793, in _LVPlotter._lv_box_ends(self, vals)
#    1790 vals = np.asarray(vals)
#    1791 # Remove infinite values while handling a 'object' dtype
#    1792 # that can come from pd.Float64Dtype() input
# -> 1793 with pd.option_context('mode.use_inf_as_null', True):
#    1794     vals = vals[~pd.isnull(vals)]
#    1795 n = len(vals)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:480, in option_context.__enter__(self)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#     149     root, k = _get_root(key)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:132, in _get_single_key(pat, silent)
#     130     if not silent:
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#     134     raise OptionError("Pattern matched multiple keys")
#
# OptionError: No such keys(s): 'mode.use_inf_as_null'

# %% [markdown]
# ## Violin Plot
#
# * Gráficos que ideal para visualizar a distribuição de variáveis.
# * Combinação do Boxplot com o KDE.
# * Funciona bem para distribuições com picos.
# * Permite uma visualização mais rica do que com o Boxplot normal.

# %% [markdown]
# **Violin Plot**

# %%
sns.catplot(x="day", y="total_bill", kind="violin", data=tips)
# Out:
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/felipedesouzafrancisco/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# **Violin Plot horizontal**

# %%
sns.catplot(x="total_bill", y="day", kind="violin", data=tips)

# %% [markdown]
# **Usando o parâmetro Hue para ter uma terceira variável **

# %%
sns.catplot(x="day", y="total_bill", hue="time", kind="violin", data=tips);

# %% [markdown]
# * **É possível dividir o violin plot com o parâmetro split.**
# * **Isso é útil quando temos muitos dados para exibir.**

# %%
sns.catplot(x="day", y="total_bill", hue="sex", split=True , kind="violin", data=tips);

# %% [markdown]
# * **Usando o parametro inner para preencher o violin plot com observações**
# * **Útil para destacar bem as partes que possuem mais dados**

# %%
sns.catplot(x="day", y="total_bill", hue="sex", split=True , inner="stick", palette="pastel", kind="violin", data=tips);

# %% [markdown]
# * **Podemos combinar também um gráfico de swarm com o Violin Plot**
# * **Dessa forma fica mais explicito ainda a frequencia de pontos nas partes do "violino"**

# %%
sns.catplot(x="day", y="total_bill", palette="pastel", kind="violin", data=tips);
sns.swarmplot(x="day", y="total_bill", color="k", size=3, data=tips)

# %% [markdown]
# ## Visualizando a distribuição de um Dataset

# %% [markdown]
# **Histograma**
#
# * O método histograma tenta encontrar a melhor quantidade de bins.

# %%
sns.set(color_codes=True)

# %%
sns.distplot(tips.total_bill, kde=False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 sns.histplot(tips.total_bill)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/distributions.py:1438, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1427 estimate_kws = dict(
#    1428     stat=stat,
#    1429     bins=bins,
#    (...)
#    1433     cumulative=cumulative,
#    1434 )
#    1436 if p.univariate:
# -> 1438     p.plot_univariate_histogram(
#    1439         multiple=multiple,
#    1440         element=element,
#    1441         fill=fill,
#    1442         shrink=shrink,
#    1443         common_norm=common_norm,
#    1444         common_bins=common_bins,
#    1445         kde=kde,
#    1446         kde_kws=kde_kws,
#    1447         color=color,
#    1448         legend=legend,
#    1449         estimate_kws=estimate_kws,
#    1450         line_kws=line_kws,
#    1451         **kwargs,
#    1452     )
#    1454 else:
#    1456     p.plot_bivariate_histogram(
#    1457         common_bins=common_bins,
#    1458         common_norm=common_norm,
#    (...)
#    1468         **kwargs,
#    1469     )
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/distributions.py:431, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     428 histograms = {}
#     430 # Do pre-compute housekeeping related to multiple groups
# --> 431 all_data = self.comp_data.dropna()
#     432 all_weights = all_data.get("weights", None)
#     434 if set(self.variables) - {"x", "y"}:  # Check if we'll have multiple histograms
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119, in VectorPlotter.comp_data(self)
#    1117 grouped = self.plot_data[var].groupby(self.converters[var], sort=False)
#    1118 for converter, orig in grouped:
# -> 1119     with pd.option_context('mode.use_inf_as_null', True):
#    1120         orig = orig.dropna()
#    1121         if var in self.var_levels:
#    1122             # TODO this should happen in some centralized location
#    1123             # it is similar to GH2419, but more complicated because
#    1124             # supporting `order` in categorical plots is tricky
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:480, in option_context.__enter__(self)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#     149     root, k = _get_root(key)
#
# File ~/Documents/repositorios/data_science_stack_academy/.venv/lib/python3.12/site-packages/pandas/_config/config.py:132, in _get_single_key(pat, silent)
#     130     if not silent:
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#     134     raise OptionError("Pattern matched multiple keys")
#
# OptionError: No such keys(s): 'mode.use_inf_as_null'

# %% [markdown]
# **Plotando um histograma para uma distribuição normal**

# %% [markdown]
# * Importa o Numpy para geração aleatoria de dados

# %%
import numpy as np

# %% [markdown]
# * Gera 100 valores aleatorios em uma distribuição normal

# %%
x = np.random.normal(size=100)

# %% [markdown]
# * Mostra Dados aleatorios na variável **x**

# %%
x

# %% [markdown]
# * Plota o histograma para a variável x

# %%
sns.distplot(x);

# %% [markdown]
# **Plota o Histograma com bins=20 e KDE=True**

# %%
sns.distplot(tips.total_bill, bins=50, kde=True)

# %% [markdown]
# **Visualizando apenas o KDE**

# %%
sns.distplot(tips.total_bill, hist=False)

# %% [markdown]
# ** Parâmetro rug**

# %%
sns.distplot(tips.total_bill, hist=True, rug=True)

# %% [markdown]
# ## Jointplot (ScatterPlot e Histograma)

# %% [markdown]
# * Quando queremos ver a distribuição de duas variáveis podemos usar o jointplot.
# * União de gráficos do tipo Scatter Plot e Histogramas para as duas variáveis.
# * Mostra o Scatter plot para as duas variáveis e um histograma para cada variável separadamente.

# %%
sns.jointplot(x="tip", y="total_bill", color='r', data=tips)

# %% [markdown]
# ## Hexbin Plots

# %% [markdown]
# * Adequado para visualização de grande conjuntos de dados.
# * Tende a funcionar melhor com as cores em branco de fundo

# %%
sns.jointplot(x="tip", y="total_bill", color='r', kind="hex", data=tips)

# %% [markdown]
# **Usando o KDE para Plotar mais de uma variável**

# %%
sns.jointplot(x="tip", y="total_bill", color='b', kind="kde", data=tips)

# %% [markdown]
# ## Visualizando relacionamentos emparelhados

# %% [markdown]
# * Plot multiplas variáveis de um dataset.
# * Cria uma matriz de eixos de mostrar a relação de cada par de colunas no dataframe.
# * Por padrão plota também um histograma de cada coluna no dataframe na diagonal da matriz.

# %%
sns.pairplot(tips);

# %% [markdown]
# ** Carrega o dataset iris**

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()

# %% [markdown]
# **Plot pares emparelhados segregando pela coluna species**

# %%
sns.pairplot(iris, hue="species", palette="Set1");

# %% [markdown]
# ** Plotando Scatter plots com regressão**

# %%
sns.pairplot(iris, kind="reg");

# %% [markdown]
# ** Plotando histogramas na diagonal**

# %%
sns.pairplot(iris,hue="species", diag_kind="hist");

# %% [markdown]
# **Plotando apenas duas colunas do dataframe**

# %%
sns.pairplot(iris, hue="species", vars=["sepal_width", "sepal_length"], palette="husl");

# %% [markdown]
# ## Gráficos de Correlação

# %% [markdown]
# * Útil para visualizar se existem correlações positivas ou negativas entre colunas
# * Método corr() do pandas possibilita calcular correlação por tipo **spearman** ou **pearson**

# %%
correlacoes = tips.corr()

# %%
correlacoes

# %%
ax = sns.heatmap(correlacoes)

# %% [markdown]
# **Exibe os valores de correlação**

# %%
ax = sns.heatmap(correlacoes, annot=True)

# %% [markdown]
# ** Visualizando a correlação de colunas do Dataframe Iris**

# %%
correlacoes = iris.corr()

# %%
correlacoes

# %%
ax = sns.heatmap(correlacoes, cmap='PuOr', annot=True)
